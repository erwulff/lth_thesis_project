# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import uproot

# %%
from sklearn.model_selection import train_test_split

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader

# %%
BIN = '../data/all_jets_split_data/'

set1 = pd.read_pickle(BIN + 'sub_train_all_jets_%d' % 0)
set2 = pd.read_pickle(BIN + 'sub_train_all_jets_%d' % 1)
set3 = pd.read_pickle(BIN + 'sub_train_all_jets_%d' % 2)
set4 = pd.read_pickle(BIN + 'sub_train_all_jets_%d' % 3)

# %% [markdown]
# Checking the shapes we see that not all datasets contain the same number of jets. That is as expected since not all events contain the same number of jets and we put the same number of events in each dataset.

# %%
print(set1.shape, set2.shape, set3.shape, set4.shape)
# Out:
# (5123030, 4) (5819647, 4) (5838824, 4) (5840365, 4)

# %%
set1.head()
# Out:
#          pT       eta       phi          E
# 0  7.408051 -0.757578  2.070008   9.727860
# 1  7.720862 -0.708688 -2.350764   9.837836
# 2  7.842499  1.429662 -1.732487  17.425312
# 3  7.839984 -0.800806 -0.558142  10.635708
# 4  7.900827  0.303174  0.390142   8.313729

# %%
for set in [set1, set2, set3, set4]:
    plt.figure()
    plt.hist(set['pT'], bins=100, range=(0,600))
    plt.xlabel(r'$p_T$')

# %%
all_pt = np.concatenate([np.array(set1['pT']), np.array(set2['pT']), np.array(set3['pT']), np.array(set4['pT'])])

# %%
all_pt.shape
# Out:
# (22621866,)

# %%
20492120 / 4
# Out:
# 5123030.0

# %%
plt.figure()
plt.hist(all_pt, bins=100, range=(0, 600))
plt.xlabel(r'$p_T$')
# Out:
# Text(0.5, 0, '$p_T$')
