# %% [markdown]
# # Jet Compression using an Autoencoder

# %%
import sys
BIN = '../../'
sys.path.append(BIN)
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import pandas as pd

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset

from my_nn_modules import AE_big, get_data, fit

import my_matplotlib_style as ms
mpl.rc_file(BIN + 'my_matplotlib_rcparams')

# %%
force_cpu = False

if force_cpu:
    device = torch.device('cpu')
else:
    if torch.cuda.is_available():
        device = torch.device('cuda')
    else:
        device = torch.device('cpu')
print('Using device:', device)
# Out:
# Using device: cpu

# %% [markdown]
# ## Loading and preparing the data

# %%
# Load data
train = pd.read_pickle(BIN + 'processed_data/train.pkl')
test = pd.read_pickle(BIN + 'processed_data/test.pkl')

train.head(10)
# Out:
#                  pT       eta       phi            E
# 1367643  300.752869  0.118391 -1.460827   303.719818
# 1739612   79.819145  4.535507 -1.185196  3722.832764
# 546066   220.472305  1.314261 -0.943992   440.195190
# 213212    74.533775  0.010658 -0.424795    74.770332
# 150544   220.668121  2.432910 -2.308348  1266.681030
# 574837   159.841782  0.731125 -1.150598   207.133514
# 1171687  306.125305  0.702473  0.437615   385.713013
# 1608254  189.011673 -1.387443  0.490634   403.126709
# 1618830  194.996719 -1.022815 -1.560437   306.534515
# 637947   186.887146 -0.621282 -0.465523   226.002701

# %% [markdown]
# ## Normalizing and splitting into train and test datasets

# %%
# Normalize
train_mean = train.mean()
train_std = train.std()

train = (train - train_mean) / train_std
# Is this the right way to normalize? (only using train mean and std to normalize both train and test)
test = (test - train_mean) / train_std

train_x = train
test_x = test
train_y = train_x  # y = x since we are building and AE
test_y = test_x

train_ds = TensorDataset(torch.tensor(train_x.values), torch.tensor(train_y.values))
valid_ds = TensorDataset(torch.tensor(test_x.values), torch.tensor(test_y.values))

# %% [markdown]
# ## Training

# %%
bs = 256  # batch size
train_dl, valid_dl = get_data(train_ds, valid_ds, bs)
loss_func = nn.MSELoss()

# %%
class AE_3D_v3(nn.Module):
    def __init__(self, n_features=4):
        super(AE_3D_v3, self).__init__()
        self.en1 = nn.Linear(n_features, 8)
        self.en2 = nn.Linear(8, 6)
        self.en3 = nn.Linear(6, 3)
        self.de1 = nn.Linear(3, 6)
        self.de2 = nn.Linear(6, 8)
        self.de3 = nn.Linear(8, n_features)
        self.tanh = nn.Tanh()

    def encode(self, x):
        return self.en3(self.tanh(self.en2(self.tanh(self.en1(x)))))

    def decode(self, x):
        return self.de3(self.tanh(self.de2(self.tanh(self.de1(self.tanh(x))))))

    def forward(self, x):
        z = self.encode(x)
        return self.decode(z)

# %%
n_features = len(train.loc[0])
model = AE_3D_v3()

# %%
# Training
epochs_list = [10, 5, 3, 2, 2]
lrs = [1e-3, 3e-4, 1e-4, 3e-5, 1e-5]
for ii, epochs in enumerate(epochs_list):
    print('Setting learning rate to %.1e' % lrs[ii])
    opt = optim.Adam(model.parameters(), lr=lrs[ii])
    fit(epochs, model, loss_func, opt, train_dl, valid_dl, device)
# Out:
# Setting learning rate to 1.0e-03
# Epoch 0: Validation loss = 0.00302844051827725 Time: 0:00:59.896307
# Epoch 1: Validation loss = 0.0010232120597966198 Time: 0:02:03.885945
# Epoch 2: Validation loss = 0.0006463867314264205 Time: 0:03:09.596463
# Epoch 3: Validation loss = 0.0005218631344070979 Time: 0:04:16.212942
# Epoch 4: Validation loss = 0.0003402080456733282 Time: 0:05:19.151623
# Epoch 5: Validation loss = 0.00028206416109794304 Time: 0:06:20.936987
# Epoch 6: Validation loss = 0.00032599865870637854 Time: 0:07:21.785091
# Epoch 7: Validation loss = 0.00022966835347376177 Time: 0:08:26.589775
# Epoch 8: Validation loss = 0.00020834847809401887 Time: 0:09:22.961168
# Epoch 9: Validation loss = 0.00019640721162091673 Time: 0:10:19.736304
# Setting learning rate to 3.0e-04
# Epoch 0: Validation loss = 0.0001695446409266428 Time: 0:00:57.402486
# Epoch 1: Validation loss = 0.00016276626401791244 Time: 0:01:56.578463
# Epoch 2: Validation loss = 0.00016173686708958682 Time: 0:03:00.265027
# Epoch 3: Validation loss = 0.00015981062970534017 Time: 0:04:06.334208
# Epoch 4: Validation loss = 0.00014978125457998877 Time: 0:05:15.605994
# Setting learning rate to 1.0e-04
# Epoch 0: Validation loss = 0.0001443062161071965 Time: 0:01:04.048459
# Epoch 1: Validation loss = 0.0001424363028110505 Time: 0:02:06.961888
# Epoch 2: Validation loss = 0.00017537998048567586 Time: 0:03:11.501547
# Setting learning rate to 3.0e-05
# Epoch 0: Validation loss = 0.00013640199506727182 Time: 0:01:02.973481
# Epoch 1: Validation loss = 0.00013619213172301315 Time: 0:02:05.894806
# Setting learning rate to 1.0e-05
# Epoch 0: Validation loss = 0.00013447159142716751 Time: 0:01:08.335189
# Epoch 1: Validation loss = 0.00013449791069004995 Time: 0:02:14.940794

# %%
opt = optim.Adam(model.parameters(), lr=1e-5)
fit(10, model, loss_func, opt, train_dl, valid_dl, device)
# Out:
# Epoch 0: Validation loss = 0.00013330236658576984 Time: 0:01:00.950094
# Epoch 1: Validation loss = 0.000132944933585187 Time: 0:02:00.595740
# Epoch 2: Validation loss = 0.0001331475630086911 Time: 0:03:03.505115
# Epoch 3: Validation loss = 0.00013313074925589446 Time: 0:04:01.233636
# Epoch 4: Validation loss = 0.00013247830033472394 Time: 0:05:00.434232
# Epoch 5: Validation loss = 0.00013227181823541063 Time: 0:06:05.352416
# Epoch 6: Validation loss = 0.00013290344166485378 Time: 0:07:04.896050
# Epoch 7: Validation loss = 0.0001317088021313545 Time: 0:08:02.075184
# Epoch 8: Validation loss = 0.00013183958852346498 Time: 0:09:02.799634
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-fbc96c0c1133> in <module>
#       1 opt = optim.Adam(model.parameters(), lr=1e-5)
# ----> 2 fit(10, model, loss_func, opt, train_dl, valid_dl, device)
#
# ~/Documents/LTH/Examensarbete/lth_thesis_project/my_nn_modules.py in fit(epochs, model, loss_func, opt, train_dl, valid_dl, device)
#     220             xb = xb.to(device)
#     221             yb = yb.to(device)
# --> 222             loss_batch(model, loss_func, xb, yb, opt)
#     223
#     224         model.eval()
#
# ~/Documents/LTH/Examensarbete/lth_thesis_project/my_nn_modules.py in loss_batch(model, loss_func, xb, yb, opt)
#     206
#     207     if opt is not None:
# --> 208         loss.backward()
#     209         opt.step()
#     210         opt.zero_grad()
#
# ~/miniconda3/envs/fastairoot/lib/python3.7/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     116                 products. Defaults to ``False``.
#     117         """
# --> 118         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     119
#     120     def register_hook(self, hook):
#
# ~/miniconda3/envs/fastairoot/lib/python3.7/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      91     Variable._execution_engine.run_backward(
#      92         tensors, grad_tensors, retain_graph, create_graph,
# ---> 93         allow_unreachable=True)  # allow_unreachable flag
#      94
#      95
#
# KeyboardInterrupt:

# %%
opt = optim.Adam(model.parameters(), lr=1e-5)
fit(10, model, loss_func, opt, train_dl, valid_dl, device)

# %%
opt = optim.Adam(model.parameters(), lr=3e-6)
fit(10, model, loss_func, opt, train_dl, valid_dl, device)

# %%
opt = optim.Adam(model.parameters(), lr=3e-6)
fit(10, model, loss_func, opt, train_dl, valid_dl, device)

# %%
opt = optim.Adam(model.parameters(), lr=1e-6)
fit(10, model, loss_func, opt, train_dl, valid_dl, device)

# %%
# saving the model for later inference (if training is to be continued another saving method is recommended)
#save_path = './models/AE_3D_bs256_loss49eneg7.pt'
#torch.save(model.state_dict(), save_path)
# model_big = AE_big()
# model_big.load_state_dict(torch.load(save_path))
# model_big.eval()

# %% [markdown]
# ## Evaluation

# %%
model.eval()
# Out:
# AE_3D_v3(
#   (en1): Linear(in_features=4, out_features=8, bias=True)
#   (en2): Linear(in_features=8, out_features=6, bias=True)
#   (en3): Linear(in_features=6, out_features=3, bias=True)
#   (de1): Linear(in_features=3, out_features=6, bias=True)
#   (de2): Linear(in_features=6, out_features=8, bias=True)
#   (de3): Linear(in_features=8, out_features=4, bias=True)
#   (tanh): Tanh()
# )

# %%
# Print a few tensors, still normalized
print('Comparing input and output:')
for ii in np.arange(100, 105):
    data = valid_ds.tensors[0][ii]
    pred = model(data)
    print('Inp:', data)
    print('Out:', pred)
    print(' ')
# Out:
# Comparing input and output:
# Inp: tensor([ 1.6863, -0.7095,  1.6946,  0.2721])
# Out: tensor([ 1.6933, -0.6953,  1.6818,  0.2789], grad_fn=<AddBackward0>)
#
# Inp: tensor([ 0.1766, -0.1649, -0.0310, -0.5931])
# Out: tensor([ 0.1767, -0.1647, -0.0297, -0.5976], grad_fn=<AddBackward0>)
#
# Inp: tensor([-0.3746,  0.6508,  1.3037, -0.5510])
# Out: tensor([-0.3818,  0.6431,  1.3020, -0.5478], grad_fn=<AddBackward0>)
#
# Inp: tensor([-0.3711, -0.0072,  1.0894, -0.7293])
# Out: tensor([-0.3746, -0.0106,  1.0947, -0.7302], grad_fn=<AddBackward0>)
#
# Inp: tensor([-0.7818, -0.3965,  1.1572, -0.7662])
# Out: tensor([-0.7852, -0.3928,  1.1658, -0.7658], grad_fn=<AddBackward0>)

# %%
# Print a few tensors, now not normalized
print('Comparing input and output:')
for ii in np.arange(100, 105):
    data = valid_ds.tensors[0][ii]
    pred = model(data).detach().numpy()
    pred = np.multiply(pred, train_std.values)
    pred = np.add(pred, train_mean.values)
    data = np.multiply(data, train_std.values)
    data = np.add(data, train_mean.values)
    print('Inp:', data)
    print('Out:', pred)
    print(' ')
# Out:
# Comparing input and output:
# Inp: tensor([430.8397,  -1.1533,   3.0955, 751.4479])
# Out: [431.6941     -1.1306516   3.0722122 755.2617   ]
#
# Inp: tensor([ 2.4776e+02, -2.8475e-01, -4.7715e-02,  2.5939e+02])
# Out: [ 2.4777614e+02 -2.8446224e-01 -4.5313358e-02  2.5681821e+02]
#
# Inp: tensor([180.9266,   1.0163,   2.3835, 283.3568])
# Out: [180.04788     1.003952    2.3804436 285.12933  ]
#
# Inp: tensor([ 1.8135e+02, -3.3156e-02,  1.9931e+00,  1.8195e+02])
# Out: [ 1.8092674e+02 -3.8689148e-02  2.0028443e+00  1.8140704e+02]
#
# Inp: tensor([131.5479,  -0.6542,   2.1167, 160.9622])
# Out: [131.1286     -0.6482704   2.1322267 161.21176  ]

# %%
plt.close('all')
unit_list = ['[GeV]', '[rad]', '[rad]', '[GeV]']
variable_list = [r'$p_T$', r'$\eta$', r'$\phi$', r'$E$']
line_style = ['--', '-']
colors = ['orange', 'c']
markers = ['*', 's']


# Histograms
idxs = (0, 100000)  # Choose events to compare
data = torch.tensor(test_x[idxs[0]:idxs[1]].values)
pred = model(data).detach().numpy()
pred = np.multiply(pred, train_std.values)
pred = np.add(pred, train_mean.values)
data = np.multiply(data, train_std.values)
data = np.add(data, train_mean.values)

alph = 0.8
n_bins = 50
for kk in np.arange(4):
    plt.figure(kk + 4)
    n_hist_data, bin_edges, _ = plt.hist(data[:, kk], color=colors[1], label='Input', alpha=1, bins=n_bins)
    n_hist_pred, _, _ = plt.hist(pred[:, kk], color=colors[0], label='Output', alpha=alph, bins=bin_edges)
    plt.suptitle(train.columns[kk])
    plt.xlabel(variable_list[kk] + ' ' + unit_list[kk])
    plt.ylabel('Number of events')
    ms.sciy()

# %%
# Plot input on top of output
idxs = (0, 100)  # Choose events to compare
data = torch.tensor(test_x[idxs[0]:idxs[1]].values)
pred = model(data).detach().numpy()
pred = np.multiply(pred, train_std.values)
pred = np.add(pred, train_mean.values)
data = np.multiply(data, train_std.values)
data = np.add(data, train_mean.values)

for kk in np.arange(4):
    plt.figure(kk)
    plt.plot(data[:, kk], color=colors[1], label='Input', linestyle=line_style[1], marker=markers[1])
    plt.plot(pred[:, kk], color=colors[0], label='Output', linestyle=line_style[0], marker=markers[0])
    plt.suptitle(train.columns[kk])
    plt.xlabel('Event')
    plt.ylabel(variable_list[kk] + ' ' + unit_list[kk])
    plt.legend()
    ms.sciy()

# %% [markdown]
# ## Exploring latent space

# %%
# Plot input on top of output
idxs = (0, int(1.9e6))  # Choose events to compare
data = torch.tensor(test_x[idxs[0]:idxs[1]].values)
latent = model.encode(data).detach().numpy()

# %%
for ii in np.arange(latent.shape[1]):
    plt.figure()
    plt.hist(latent[:, ii], label='$z_%d$' % (ii + 1), color='m', bins=100)
    plt.suptitle('Latent variable #%d' % (ii + 1))
    plt.legend()
    ms.sciy()

# %% [markdown]
# ## 3D scatter plot

# %%
from mpl_toolkits.mplot3d import Axes3D

idxs = (0, 10000)  # Choose events to compare
data = torch.tensor(test_x[idxs[0]:idxs[1]].values)
latent = model.encode(data).detach().numpy()

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(latent[:, 0], latent[:, 1], latent[:, 2], s=1)
ax.set_xlabel(r'$z_1$')
ax.set_ylabel(r'$z_2$')
ax.set_zlabel(r'$z_3$')
# Out:
# Text(0.5, 0, '$z_3$')

# %% [markdown]
# ## 2D scatter plots

# %%
mksz = 1

plt.figure()
plt.scatter(latent[:, 0], latent[:, 1], s=mksz)
plt.xlabel(r'$z_1$')
plt.ylabel(r'$z_2$')

plt.figure()
plt.scatter(latent[:, 0], latent[:, 2], s=mksz)
plt.xlabel(r'$z_1$')
plt.ylabel(r'$z_3$')

plt.figure()
plt.scatter(latent[:, 1], latent[:, 2], s=mksz)
plt.xlabel(r'$z_2$')
plt.ylabel(r'$z_3$')
# Out:
# Text(0, 0.5, '$z_3$')
