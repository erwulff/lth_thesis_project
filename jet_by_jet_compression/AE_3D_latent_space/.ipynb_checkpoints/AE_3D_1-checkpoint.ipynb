# %% [markdown]
# # Jet Compression using an Autoencoder

# %%
import sys
BIN = '../../'
sys.path.append(BIN)
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import pandas as pd

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset

from my_nn_modules import AE_big, get_data, fit

import my_matplotlib_style as ms
mpl.rc_file(BIN + 'my_matplotlib_rcparams')

# %%
force_cpu = False

if force_cpu:
    device = torch.device('cpu')
else:
    if torch.cuda.is_available():
        device = torch.device('cuda')
    else:
        device = torch.device('cpu')
print('Using device:', device)
# Out:
# Using device: cpu

# %% [markdown]
# ## Loading and preparing the data

# %%
# Load data
train = pd.read_pickle(BIN + 'processed_data/train.pkl')
test = pd.read_pickle(BIN + 'processed_data/test.pkl')

train.head(10)
# Out:
#                  pT       eta       phi            E
# 1367643  300.752869  0.118391 -1.460827   303.719818
# 1739612   79.819145  4.535507 -1.185196  3722.832764
# 546066   220.472305  1.314261 -0.943992   440.195190
# 213212    74.533775  0.010658 -0.424795    74.770332
# 150544   220.668121  2.432910 -2.308348  1266.681030
# 574837   159.841782  0.731125 -1.150598   207.133514
# 1171687  306.125305  0.702473  0.437615   385.713013
# 1608254  189.011673 -1.387443  0.490634   403.126709
# 1618830  194.996719 -1.022815 -1.560437   306.534515
# 637947   186.887146 -0.621282 -0.465523   226.002701

# %% [markdown]
# ## Normalizing and splitting into train and test datasets

# %%
# Normalize
train_mean = train.mean()
train_std = train.std()

train = (train - train_mean) / train_std
# Is this the right way to normalize? (only using train mean and std to normalize both train and test)
test = (test - train_mean) / train_std

train_x = train
test_x = test
train_y = train_x  # y = x since we are building and AE
test_y = test_x

train_ds = TensorDataset(torch.tensor(train_x.values), torch.tensor(train_y.values))
valid_ds = TensorDataset(torch.tensor(test_x.values), torch.tensor(test_y.values))

# %% [markdown]
# ## Training

# %%
bs = 256  # batch size
train_dl, valid_dl = get_data(train_ds, valid_ds, bs)
loss_func = nn.MSELoss()

# %%
class AE_3D(nn.Module):
    def __init__(self, n_features=4):
        super(AE_3D, self).__init__()
        self.en1 = nn.Linear(n_features, 100)
        self.en2 = nn.Linear(100, 100)
        self.en3 = nn.Linear(100, 50)
        self.en4 = nn.Linear(50, 3)
        self.de1 = nn.Linear(3, 50)
        self.de2 = nn.Linear(50, 100)
        self.de3 = nn.Linear(100, 100)
        self.de4 = nn.Linear(100, n_features)
        self.tanh = nn.Tanh()

    def encode(self, x):
        return self.en4(self.tanh(self.en3(self.tanh(self.en2(self.tanh(self.en1(x)))))))

    def decode(self, x):
        return self.de4(self.tanh(self.de3(self.tanh(self.de2(self.tanh(self.de1(self.tanh(x))))))))

    def forward(self, x):
        z = self.encode(x)
        return self.decode(z)

# %%
n_features = len(train.loc[0])
model = AE_3D()

# %%
# Training
epochs_list = [7, 5, 3, 2, 2]
lrs = [1e-3, 3e-4, 1e-4, 3e-5, 1e-5]
for ii, epochs in enumerate(epochs_list):
    print('Setting learning rate to %.1e' % lrs[ii])
    opt = optim.Adam(model.parameters(), lr=lrs[ii])
    fit(epochs, model, loss_func, opt, train_dl, valid_dl, device)
# Out:
# Setting learning rate to 1.0e-03
# Epoch 0: Validation loss = 0.00017603197471304473
# Epoch 1: Validation loss = 8.091510133885959e-05
# Epoch 2: Validation loss = 0.00011039881159469688
# Epoch 3: Validation loss = 0.0002650714985995046
# Epoch 4: Validation loss = 0.00014099723599296952
# Epoch 5: Validation loss = 0.00020071767818020803
# Epoch 6: Validation loss = 0.00117086403169179
# Setting learning rate to 3.0e-04
# Epoch 0: Validation loss = 6.17157655257305e-05
# Epoch 1: Validation loss = 3.731537382444039e-05
# Epoch 2: Validation loss = 4.7193269498272006e-05
# Epoch 3: Validation loss = 2.4932035850048778e-05
# Epoch 4: Validation loss = 6.896592433341458e-05
# Setting learning rate to 1.0e-04
# Epoch 0: Validation loss = 1.5724536003497152e-05
# Epoch 1: Validation loss = 1.2287645378273307e-05
# Epoch 2: Validation loss = 1.039139417792039e-05
# Setting learning rate to 3.0e-05
# Epoch 0: Validation loss = 9.03073291080278e-06
# Epoch 1: Validation loss = 9.86770315907312e-06
# Setting learning rate to 1.0e-05
# Epoch 0: Validation loss = 8.073018730301714e-06
# Epoch 1: Validation loss = 8.21129868907247e-06

# %%
opt = optim.Adam(model.parameters(), lr=1e-5)
fit(10, model, loss_func, opt, train_dl, valid_dl, device)
# Out:
# Epoch 0: Validation loss = 7.695517482091405e-06
# Epoch 1: Validation loss = 7.5163891261371925e-06
# Epoch 2: Validation loss = 7.1953342895614386e-06
# Epoch 3: Validation loss = 7.448789087397205e-06
# Epoch 4: Validation loss = 7.2721426179610225e-06
# Epoch 5: Validation loss = 9.928809638718931e-06
# Epoch 6: Validation loss = 6.9571048894221435e-06
# Epoch 7: Validation loss = 6.752933344651056e-06
# Epoch 8: Validation loss = 6.742996161713348e-06
# Epoch 9: Validation loss = 6.8240871824387265e-06

# %%
opt = optim.Adam(model.parameters(), lr=1e-5)
fit(10, model, loss_func, opt, train_dl, valid_dl, device)
# Out:
# Epoch 0: Validation loss = 6.321043694619056e-06
# Epoch 1: Validation loss = 8.24216161703786e-06
# Epoch 2: Validation loss = 6.298849555835363e-06
# Epoch 3: Validation loss = 6.585399527897871e-06
# Epoch 4: Validation loss = 6.131870944824392e-06
# Epoch 5: Validation loss = 5.9407863830013775e-06
# Epoch 6: Validation loss = 6.020850098256116e-06
# Epoch 7: Validation loss = 5.7850196012821525e-06
# Epoch 8: Validation loss = 5.929347275129853e-06
# Epoch 9: Validation loss = 6.028576937827051e-06

# %%
opt = optim.Adam(model.parameters(), lr=3e-6)
fit(10, model, loss_func, opt, train_dl, valid_dl, device)
# Out:
# Epoch 0: Validation loss = 5.515653482883391e-06
# Epoch 1: Validation loss = 5.596697840701163e-06
# Epoch 2: Validation loss = 5.5680680078547035e-06
# Epoch 3: Validation loss = 5.906645471016332e-06
# Epoch 4: Validation loss = 5.322069334341119e-06
# Epoch 5: Validation loss = 5.291601027851806e-06
# Epoch 6: Validation loss = 5.2543672813403084e-06
# Epoch 7: Validation loss = 5.277770779155502e-06
# Epoch 8: Validation loss = 5.236537455167524e-06
# Epoch 9: Validation loss = 5.170713190694528e-06

# %%
opt = optim.Adam(model.parameters(), lr=3e-6)
fit(10, model, loss_func, opt, train_dl, valid_dl, device)
# Out:
# Epoch 0: Validation loss = 5.371294389633426e-06
# Epoch 1: Validation loss = 5.190125304569569e-06
# Epoch 2: Validation loss = 5.114470897565232e-06
# Epoch 3: Validation loss = 5.16573589222497e-06
# Epoch 4: Validation loss = 5.277193059511757e-06
# Epoch 5: Validation loss = 5.053343887035287e-06
# Epoch 6: Validation loss = 5.019337806400192e-06
# Epoch 7: Validation loss = 5.077840002629004e-06
# Epoch 8: Validation loss = 4.985117955069825e-06
# Epoch 9: Validation loss = 4.907559049069742e-06

# %%
opt = optim.Adam(model.parameters(), lr=1e-6)
fit(10, model, loss_func, opt, train_dl, valid_dl, device)
# Out:
# Epoch 0: Validation loss = 4.881433791693959e-06
# Epoch 1: Validation loss = 4.868484201733688e-06
# Epoch 2: Validation loss = 4.871370985338232e-06
# Epoch 3: Validation loss = 4.826788240802075e-06
# Epoch 4: Validation loss = 4.824666058828482e-06
# Epoch 5: Validation loss = 4.89907740951939e-06
# Epoch 6: Validation loss = 4.804004636948945e-06
# Epoch 7: Validation loss = 4.8216495382901245e-06
# Epoch 8: Validation loss = 4.793463676151396e-06
# Epoch 9: Validation loss = 4.915171052152102e-06

# %%
# saving the model for later inference (if training is to be continued another saving method is recommended)
#save_path = './models/AE_3D_bs256_loss49eneg7.pt'
#torch.save(model.state_dict(), save_path)
# model_big = AE_big()
# model_big.load_state_dict(torch.load(save_path))
# model_big.eval()

# %% [markdown]
# ## Evaluation

# %%
model.eval()
# Out:
# AE_3D(
#   (en1): Linear(in_features=4, out_features=100, bias=True)
#   (en2): Linear(in_features=100, out_features=100, bias=True)
#   (en3): Linear(in_features=100, out_features=50, bias=True)
#   (en4): Linear(in_features=50, out_features=3, bias=True)
#   (de1): Linear(in_features=3, out_features=50, bias=True)
#   (de2): Linear(in_features=50, out_features=100, bias=True)
#   (de3): Linear(in_features=100, out_features=100, bias=True)
#   (de4): Linear(in_features=100, out_features=4, bias=True)
#   (tanh): Tanh()
# )

# %%
# Print a few tensors, still normalized
print('Comparing input and output:')
for ii in np.arange(100, 105):
    data = valid_ds.tensors[0][ii]
    pred = model(data)
    print('Inp:', data)
    print('Out:', pred)
    print(' ')
# Out:
# Comparing input and output:
# Inp: tensor([ 1.6863, -0.7095,  1.6946,  0.2721])
# Out: tensor([ 1.6850, -0.7079,  1.6961,  0.2755], grad_fn=<AddBackward0>)
#
# Inp: tensor([ 0.1766, -0.1649, -0.0310, -0.5931])
# Out: tensor([ 0.1765, -0.1650, -0.0313, -0.5948], grad_fn=<AddBackward0>)
#
# Inp: tensor([-0.3746,  0.6508,  1.3037, -0.5510])
# Out: tensor([-0.3752,  0.6508,  1.3034, -0.5516], grad_fn=<AddBackward0>)
#
# Inp: tensor([-0.3711, -0.0072,  1.0894, -0.7293])
# Out: tensor([-0.3718, -0.0078,  1.0890, -0.7277], grad_fn=<AddBackward0>)
#
# Inp: tensor([-0.7818, -0.3965,  1.1572, -0.7662])
# Out: tensor([-0.7837, -0.3969,  1.1565, -0.7653], grad_fn=<AddBackward0>)

# %%
# Print a few tensors, now not normalized
print('Comparing input and output:')
for ii in np.arange(100, 105):
    data = valid_ds.tensors[0][ii]
    pred = model(data).detach().numpy()
    pred = np.multiply(pred, train_std.values)
    pred = np.add(pred, train_mean.values)
    data = np.multiply(data, train_std.values)
    data = np.add(data, train_mean.values)
    print('Inp:', data)
    print('Out:', pred)
    print(' ')
# Out:
# Comparing input and output:
# Inp: tensor([430.8397,  -1.1533,   3.0955, 751.4479])
# Out: [430.6834     -1.1507893   3.098273  753.3749   ]
#
# Inp: tensor([ 2.4776e+02, -2.8475e-01, -4.7715e-02,  2.5939e+02])
# Out: [ 2.4774980e+02 -2.8493023e-01 -4.8233680e-02  2.5844443e+02]
#
# Inp: tensor([180.9266,   1.0163,   2.3835, 283.3568])
# Out: [180.85469     1.0163406   2.3829665 282.9887   ]
#
# Inp: tensor([ 1.8135e+02, -3.3156e-02,  1.9931e+00,  1.8195e+02])
# Out: [ 1.8126143e+02 -3.4078155e-02  1.9924130e+00  1.8282242e+02]
#
# Inp: tensor([131.5479,  -0.6542,   2.1167, 160.9622])
# Out: [131.30669     -0.65472084   2.1153584  161.44592   ]

# %%
plt.close('all')
unit_list = ['[GeV]', '[rad]', '[rad]', '[GeV]']
variable_list = [r'$p_T$', r'$\eta$', r'$\phi$', r'$E$']
line_style = ['--', '-']
colors = ['orange', 'c']
markers = ['*', 's']


# Histograms
idxs = (0, 100000)  # Choose events to compare
data = torch.tensor(test_x[idxs[0]:idxs[1]].values)
pred = model(data).detach().numpy()
pred = np.multiply(pred, train_std.values)
pred = np.add(pred, train_mean.values)
data = np.multiply(data, train_std.values)
data = np.add(data, train_mean.values)

alph = 0.8
n_bins = 50
for kk in np.arange(4):
    plt.figure(kk + 4)
    n_hist_data, bin_edges, _ = plt.hist(data[:, kk], color=colors[1], label='Input', alpha=1, bins=n_bins)
    n_hist_pred, _, _ = plt.hist(pred[:, kk], color=colors[0], label='Output', alpha=alph, bins=bin_edges)
    plt.suptitle(train.columns[kk])
    plt.xlabel(variable_list[kk] + ' ' + unit_list[kk])
    plt.ylabel('Number of events')
    ms.sciy()

# %%
# Plot input on top of output
idxs = (0, 100)  # Choose events to compare
data = torch.tensor(test_x[idxs[0]:idxs[1]].values)
pred = model(data).detach().numpy()
pred = np.multiply(pred, train_std.values)
pred = np.add(pred, train_mean.values)
data = np.multiply(data, train_std.values)
data = np.add(data, train_mean.values)

for kk in np.arange(4):
    plt.figure(kk)
    plt.plot(data[:, kk], color=colors[1], label='Input', linestyle=line_style[1], marker=markers[1])
    plt.plot(pred[:, kk], color=colors[0], label='Output', linestyle=line_style[0], marker=markers[0])
    plt.suptitle(train.columns[kk])
    plt.xlabel('Event')
    plt.ylabel(variable_list[kk] + ' ' + unit_list[kk])
    plt.legend()
    ms.sciy()

# %% [markdown]
# ## Exploring latent space

# %%
# Plot input on top of output
idxs = (0, int(1.9e6))  # Choose events to compare
data = torch.tensor(test_x[idxs[0]:idxs[1]].values)
latent = model.encode(data).detach().numpy()

# %%
for ii in np.arange(latent.shape[1]):
    plt.figure()
    plt.hist(latent[:, ii], label='$z_%d$' % (ii + 1), color='m')
    plt.suptitle('Latent variable #%d' % (ii + 1))
    plt.legend()
    ms.sciy()

# %% [markdown]
# ## 3D scatter plot

# %%
from mpl_toolkits.mplot3d import Axes3D

idxs = (0, 10000)  # Choose events to compare
data = torch.tensor(test_x[idxs[0]:idxs[1]].values)
latent = model.encode(data).detach().numpy()

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(latent[:, 0], latent[:, 1], latent[:, 2], s=1)
ax.set_xlabel(r'$z_1$')
ax.set_ylabel(r'$z_2$')
ax.set_zlabel(r'$z_3$')
# Out:
# Text(0.5, 0, '$z_3$')

# %% [markdown]
# ## 2D scatter plots

# %%
mksz = 1

plt.figure()
plt.scatter(latent[:, 0], latent[:, 1], s=mksz)
plt.xlabel(r'$z_1$')
plt.ylabel(r'$z_2$')

plt.figure()
plt.scatter(latent[:, 0], latent[:, 2], s=mksz)
plt.xlabel(r'$z_1$')
plt.ylabel(r'$z_3$')

plt.figure()
plt.scatter(latent[:, 1], latent[:, 2], s=mksz)
plt.xlabel(r'$z_2$')
plt.ylabel(r'$z_3$')
# Out:
# Text(0, 0.5, '$z_3$')
