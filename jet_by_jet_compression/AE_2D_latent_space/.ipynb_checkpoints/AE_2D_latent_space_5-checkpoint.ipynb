# %% [markdown]
# # Jet Compression using an Autoencoder

# %%
import sys
BIN = '../../'
sys.path.append(BIN)
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import pandas as pd

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset

from my_nn_modules import AE_big, get_data, fit

import my_matplotlib_style as ms
mpl.rc_file(BIN + 'my_matplotlib_rcparams')

# %% [markdown]
# ## Loading and preparing the data

# %%
force_cpu = False

if force_cpu:
    device = torch.device('cpu')
else:
    if torch.cuda.is_available():
        device = torch.device('cuda')
    else:
        device = torch.device('cpu')
print('Using device:', device)
# Out:
# Using device: cpu

# %%
# Load data
train = pd.read_pickle(BIN + 'processed_data/train.pkl')
test = pd.read_pickle(BIN + 'processed_data/test.pkl')

train.head(10)
# Out:
#                  pT       eta       phi            E
# 1367643  300.752869  0.118391 -1.460827   303.719818
# 1739612   79.819145  4.535507 -1.185196  3722.832764
# 546066   220.472305  1.314261 -0.943992   440.195190
# 213212    74.533775  0.010658 -0.424795    74.770332
# 150544   220.668121  2.432910 -2.308348  1266.681030
# 574837   159.841782  0.731125 -1.150598   207.133514
# 1171687  306.125305  0.702473  0.437615   385.713013
# 1608254  189.011673 -1.387443  0.490634   403.126709
# 1618830  194.996719 -1.022815 -1.560437   306.534515
# 637947   186.887146 -0.621282 -0.465523   226.002701

# %% [markdown]
# ## Normalizing and splitting into train and test datasets

# %%
# Normalize
train_mean = train.mean()
train_std = train.std()

train = (train - train_mean) / train_std
# Is this the right way to normalize? (only using train mean and std to normalize both train and test)
test = (test - train_mean) / train_std

train_x = train
test_x = test
train_y = train_x  # y = x since we are building and AE
test_y = test_x

train_ds = TensorDataset(torch.tensor(train_x.values), torch.tensor(train_y.values))
valid_ds = TensorDataset(torch.tensor(test_x.values), torch.tensor(test_y.values))

# %% [markdown]
# ## Training

# %%
def mse_loss(input, target, size_average=None, reduce=None, reduction='mean'):
    # type: (Tensor, Tensor, Optional[bool], Optional[bool], str) -> Tensor
    r"""mse_loss(input, target, size_average=None, reduce=None, reduction='mean') -> Tensor

    Measures the element-wise mean squared error.

    See :class:`~torch.nn.MSELoss` for details.
    """
    if not (target.size() == input.size()):
        warnings.warn("Using a target size ({}) that is different to the input size ({}). "
                      "This will likely lead to incorrect results due to broadcasting. "
                      "Please ensure they have the same size.".format(target.size(), input.size()),
                      stacklevel=2)
    if size_average is not None or reduce is not None:
        reduction = _Reduction.legacy_get_string(size_average, reduce)

    ret = (input - target) ** 2
    factor = torch.full(ret.size(), 1)
    factor[:, 2] = 2.4
    ret = ret * factor
    if reduction != 'none':
        ret = torch.mean(ret) if reduction == 'mean' else torch.sum(ret)

    return ret

# %%
bs = 256  # batch size
train_dl, valid_dl = get_data(train_ds, valid_ds, bs)
loss_func = nn.MSELoss()
loss_func = mse_loss

# %%
class AE_2D_v3(nn.Module):
    def __init__(self, n_features=4):
        super(AE_2D_v3, self).__init__()
        self.en1 = nn.Linear(n_features, 100)
        self.en2 = nn.Linear(100, 200)
        self.en3 = nn.Linear(200, 100)
        self.en4 = nn.Linear(100, 2)
        self.de1 = nn.Linear(2, 100)
        self.de2 = nn.Linear(100, 200)
        self.de3 = nn.Linear(200, 100)
        self.de4 = nn.Linear(100, n_features)
        self.tanh = nn.Tanh()

    def encode(self, x):
        return self.en4(self.tanh(self.en3(self.tanh(self.en2(self.tanh(self.en1(x)))))))

    def decode(self, x):
        return self.de4(self.tanh(self.de3(self.tanh(self.de2(self.tanh(self.de1(self.tanh(x))))))))

    def forward(self, x):
        z = self.encode(x)
        return self.decode(z)


class AE_big_2D_v1(nn.Module):
    def __init__(self, n_features=4):
        super(AE_big_2D_v1, self).__init__()
        self.en1 = nn.Linear(n_features, 8)
        self.en2 = nn.Linear(8, 6)
        self.en3 = nn.Linear(6, 4)
        self.en4 = nn.Linear(4, 2)
        self.de1 = nn.Linear(2, 4)
        self.de2 = nn.Linear(4, 6)
        self.de3 = nn.Linear(6, 8)
        self.de4 = nn.Linear(8, n_features)
        self.tanh = nn.Tanh()

    def encode(self, x):
        return self.en4(self.tanh(self.en3(self.tanh(self.en2(self.tanh(self.en1(x)))))))

    def decode(self, x):
        return self.de4(self.tanh(self.de3(self.tanh(self.de2(self.tanh(self.de1(self.tanh(x))))))))

    def forward(self, x):
        z = self.encode(x)
        return self.decode(z)
    

class AE_big_2D_v2(nn.Module):
    def __init__(self, n_features=4):
        super(AE_big_2D_v2, self).__init__()
        self.en1 = nn.Linear(n_features, 8)
        self.en2 = nn.Linear(8, 6)
        self.en3 = nn.Linear(6, 4)
        self.en4 = nn.Linear(4, 3)
        self.en5 = nn.Linear(3, 2)
        self.de1 = nn.Linear(2, 3)
        self.de2 = nn.Linear(3, 4)
        self.de3 = nn.Linear(4, 6)
        self.de4 = nn.Linear(6, 8)
        self.de5 = nn.Linear(8, n_features)
        self.tanh = nn.Tanh()

    def encode(self, x):
        return self.en5(self.tanh(self.en4(self.tanh(self.en3(self.tanh(self.en2(self.tanh(self.en1(x)))))))))

    def decode(self, x):
        return self.de5(self.tanh(self.de4(self.tanh(self.de3(self.tanh(self.de2(self.tanh(self.de1(self.tanh(x))))))))))

    def forward(self, x):
        z = self.encode(x)
        return self.decode(z)

# %%
n_features = len(train.loc[0])
model = AE_2D_v3(n_features=n_features)

# %%
# Training
#epochs_list = [7, 5, 3, 2, 2]
epochs_list = [40, 40, 20, 20, 20]
lrs = [1e-3, 3e-4, 1e-4, 3e-5, 1e-5]
for ii, epochs in enumerate(epochs_list):
    print('Setting learning rate to %.1e' % lrs[ii])
    opt = optim.Adam(model.parameters(), lr=lrs[ii])
    #opt = optim.SGD(model.parameters(), lr=lrs[ii], momentum=0.9, nesterov=True)
    #opt = optim.RMSprop(model.parameters(), lr=lrs[ii], momentum=0.9)
    fit(epochs, model, loss_func, opt, train_dl, valid_dl, device)
# Out:
# Setting learning rate to 1.0e-03
# Epoch 0: Validation loss = 0.0971927414540164
# Epoch 1: Validation loss = 0.09137027682531379
# Epoch 2: Validation loss = 0.09617974823981798
# Epoch 3: Validation loss = 0.1027759776602757
# Epoch 4: Validation loss = 0.07866040441663201
# Epoch 5: Validation loss = 0.08183725387750562
# Epoch 6: Validation loss = 0.07057878676655237
# Epoch 7: Validation loss = 0.07460551097782278
# Epoch 8: Validation loss = 0.06153679289006535
# Epoch 9: Validation loss = 0.08222041099562792
# Epoch 10: Validation loss = 0.10128433055464198
# Epoch 11: Validation loss = 0.07698187555987564
# Epoch 12: Validation loss = 0.08245272671289229
# Epoch 13: Validation loss = 0.07267784215139171
# Epoch 14: Validation loss = 0.06794947688800784
# Epoch 15: Validation loss = 0.05750372089598666
# Epoch 16: Validation loss = 0.061023694254076236
# Epoch 17: Validation loss = 0.05917038486258037
# Epoch 18: Validation loss = 0.07186000168767652
# Epoch 19: Validation loss = 0.05676404941210289
# Epoch 20: Validation loss = 0.052122653019902807
# Epoch 21: Validation loss = 0.22262417586188843
# Epoch 22: Validation loss = 0.045927805252421024
# Epoch 23: Validation loss = 0.050783714030816746
# Epoch 24: Validation loss = 0.059677398827122766
# Epoch 25: Validation loss = 0.04828144825217406
# Epoch 26: Validation loss = 0.04760895879074857
# Epoch 27: Validation loss = 0.046290499073666794
# Epoch 28: Validation loss = 0.03815772030760102
# Epoch 29: Validation loss = 0.04440759978427873
# Epoch 30: Validation loss = 0.05064033633154451
# Epoch 31: Validation loss = 0.05505606360534798
# Epoch 32: Validation loss = 0.04477833011866952
# Epoch 33: Validation loss = 0.04671978935136276
# Epoch 34: Validation loss = 0.056034561361944416
# Epoch 35: Validation loss = 0.05775228520421135
# Epoch 36: Validation loss = 0.05460763292589025
# Epoch 37: Validation loss = 0.11335862712316137
# Epoch 38: Validation loss = 0.09106258601728015
# Epoch 39: Validation loss = 0.0703727837955667
# Setting learning rate to 3.0e-04
# Epoch 0: Validation loss = 0.06417967532917909
# Epoch 1: Validation loss = 0.05835029655700167
# Epoch 2: Validation loss = 0.055745724470899566
# Epoch 3: Validation loss = 0.053761707665982504
# Epoch 4: Validation loss = 0.052587517589730674
# Epoch 5: Validation loss = 0.05212231021090046
# Epoch 6: Validation loss = 0.05927755120919941
# Epoch 7: Validation loss = 0.05197568583259546
# Epoch 8: Validation loss = 0.0512148743367592
# Epoch 9: Validation loss = 0.04925974664110603
# Epoch 10: Validation loss = 0.047189165875574604
# Epoch 11: Validation loss = 0.04703914431090904
# Epoch 12: Validation loss = 0.04631668670671372
# Epoch 13: Validation loss = 0.047701095253308574
# Epoch 14: Validation loss = 0.04668843445994461
# Epoch 15: Validation loss = 0.04987293331500682
# Epoch 16: Validation loss = 0.04542853485880274
# Epoch 17: Validation loss = 0.047693332004169295
# Epoch 18: Validation loss = 0.04567323335330335
# Epoch 19: Validation loss = 0.046071566183451255
# Epoch 20: Validation loss = 0.050451417701209415
# Epoch 21: Validation loss = 0.04760384768910462
# Epoch 22: Validation loss = 0.045763367421458305
# Epoch 23: Validation loss = 0.04431370315053681
# Epoch 24: Validation loss = 0.04533581144759016
# Epoch 25: Validation loss = 0.048468910882081225
# Epoch 26: Validation loss = 0.04713270075946382
# Epoch 27: Validation loss = 0.046206225033824995
# Epoch 28: Validation loss = 0.043461661403470596
# Epoch 29: Validation loss = 0.045816277862944246
# Epoch 30: Validation loss = 0.04494290462896765
# Epoch 31: Validation loss = 0.04576713505876339
# Epoch 32: Validation loss = 0.041801125844952776
# Epoch 33: Validation loss = 0.040202870781748376
# Epoch 34: Validation loss = 0.04218789518130081
# Epoch 35: Validation loss = 0.0428229844279969
# Epoch 36: Validation loss = 0.04308912717038056
# Epoch 37: Validation loss = 0.04109838120916428
# Epoch 38: Validation loss = 0.04352197031717342
# Epoch 39: Validation loss = 0.04337309724752788
# Setting learning rate to 1.0e-04
# Epoch 0: Validation loss = 0.03978635182933301
# Epoch 1: Validation loss = 0.03955109185060692
# Epoch 2: Validation loss = 0.039086891894315606
# Epoch 3: Validation loss = 0.038551316788567415
# Epoch 4: Validation loss = 0.039108591746559264
# Epoch 5: Validation loss = 0.03808787390138159
# Epoch 6: Validation loss = 0.03770697510010306
# Epoch 7: Validation loss = 0.03825764548333061
# Epoch 8: Validation loss = 0.03852558382836394
# Epoch 9: Validation loss = 0.036891733663262566
# Epoch 10: Validation loss = 0.03741000217741084
# Epoch 11: Validation loss = 0.03720072867991554
# Epoch 12: Validation loss = 0.03701976681071162
# Epoch 13: Validation loss = 0.03674651673175636
# Epoch 14: Validation loss = 0.036706162164502856
# Epoch 15: Validation loss = 0.03611619516789116
# Epoch 16: Validation loss = 0.035717338289183456
# Epoch 17: Validation loss = 0.036531010440010274
# Epoch 18: Validation loss = 0.03604847426431019
# Epoch 19: Validation loss = 0.036346173648858456
# Setting learning rate to 3.0e-05
# Epoch 0: Validation loss = 0.03673801683100629
# Epoch 1: Validation loss = 0.03574672424403833
# Epoch 2: Validation loss = 0.03596456828680903
# Epoch 3: Validation loss = 0.035799572600287384
# Epoch 4: Validation loss = 0.03618366545706339
# Epoch 5: Validation loss = 0.036064321369574666
# Epoch 6: Validation loss = 0.035783515163837584
# Epoch 7: Validation loss = 0.03572074573319541
# Epoch 8: Validation loss = 0.03568952385942742
# Epoch 9: Validation loss = 0.03559033904467242
# Epoch 10: Validation loss = 0.03548885621018683
# Epoch 11: Validation loss = 0.035249252692433786
# Epoch 12: Validation loss = 0.03554948189790124
# Epoch 13: Validation loss = 0.03538309738424167
# Epoch 14: Validation loss = 0.035189684515511195
# Epoch 15: Validation loss = 0.035240538359710034
# Epoch 16: Validation loss = 0.03514570639964428
# Epoch 17: Validation loss = 0.035582885360894
# Epoch 18: Validation loss = 0.035586705442246534
# Epoch 19: Validation loss = 0.03517042804412237
# Setting learning rate to 1.0e-05
# Epoch 0: Validation loss = 0.03491309594082093
# Epoch 1: Validation loss = 0.034921674316048486
# Epoch 2: Validation loss = 0.035011462555131476
# Epoch 3: Validation loss = 0.03503051431007249
# Epoch 4: Validation loss = 0.034864247945581475
# Epoch 5: Validation loss = 0.035144658225458536
# Epoch 6: Validation loss = 0.03499065426152726
# Epoch 7: Validation loss = 0.034951531476181685
# Epoch 8: Validation loss = 0.03498175438026951
# Epoch 9: Validation loss = 0.03484652798297944
# Epoch 10: Validation loss = 0.034928469027036974
# Epoch 11: Validation loss = 0.03489260623145155
# Epoch 12: Validation loss = 0.034948397100309406
# Epoch 13: Validation loss = 0.034832782347914884
# Epoch 14: Validation loss = 0.03476869157657692
# Epoch 15: Validation loss = 0.0347634744537695
# Epoch 16: Validation loss = 0.03485876232623466
# Epoch 17: Validation loss = 0.03474618811776577
# Epoch 18: Validation loss = 0.03473136637161118
# Epoch 19: Validation loss = 0.034621534280356865

# %%
# Training
#epochs_list = [7, 5, 3, 2, 2]
epochs_list = [40, 40, 20, 20, 20]
lrs = [1e-4, 3e-5, 1e-5, 3e-6, 1e-6]
for ii, epochs in enumerate(epochs_list):
    print('Setting learning rate to %.1e' % lrs[ii])
    opt = optim.Adam(model.parameters(), lr=lrs[ii])
    #opt = optim.SGD(model.parameters(), lr=lrs[ii], momentum=0.9, nesterov=True)
    #opt = optim.RMSprop(model.parameters(), lr=lrs[ii], momentum=0.9)
    fit(epochs, model, loss_func, opt, train_dl, valid_dl, device)
# Out:
# Setting learning rate to 1.0e-04
# Epoch 0: Validation loss = 0.035196562561844676
# Epoch 1: Validation loss = 0.035676424886757166
# Epoch 2: Validation loss = 0.03495773649784884
# Epoch 3: Validation loss = 0.034424046531090206
# Epoch 4: Validation loss = 0.03608308360738942
# Epoch 5: Validation loss = 0.03621083822124932
# Epoch 6: Validation loss = 0.0360464371726612
# Epoch 7: Validation loss = 0.03528463299633609
# Epoch 8: Validation loss = 0.03559551264772299
# Epoch 9: Validation loss = 0.03547861367533231
# Epoch 10: Validation loss = 0.035116353761657206
# Epoch 11: Validation loss = 0.035055844526343936
# Epoch 12: Validation loss = 0.034863810540761556
# Epoch 13: Validation loss = 0.0354763115760599
# Epoch 14: Validation loss = 0.03493511851175257
# Epoch 15: Validation loss = 0.034840348955991814
# Epoch 16: Validation loss = 0.03483092562912225
# Epoch 17: Validation loss = 0.034544403466366606
# Epoch 18: Validation loss = 0.03465469314477227
# Epoch 19: Validation loss = 0.0345721001700394
# Epoch 20: Validation loss = 0.03709750039369631
# Epoch 21: Validation loss = 0.03463129922845074
# Epoch 22: Validation loss = 0.03531353506804468
# Epoch 23: Validation loss = 0.0350116619512416
# Epoch 24: Validation loss = 0.034497139915466345
# Epoch 25: Validation loss = 0.03412288011903083
# Epoch 26: Validation loss = 0.03441240896297987
# Epoch 27: Validation loss = 0.03421371289672915
# Epoch 28: Validation loss = 0.034967337001482315
# Epoch 29: Validation loss = 0.03528240966871877
# Epoch 30: Validation loss = 0.034830133422059754
# Epoch 31: Validation loss = 0.03436609159862797
# Epoch 32: Validation loss = 0.03512359332324039
# Epoch 33: Validation loss = 0.034123981217634734
# Epoch 34: Validation loss = 0.03357642119434893
# Epoch 35: Validation loss = 0.03404955010302424
# Epoch 36: Validation loss = 0.03396558579185953
# Epoch 37: Validation loss = 0.03422575125314813
# Epoch 38: Validation loss = 0.03420749700362068
# Epoch 39: Validation loss = 0.035027978637238874
# Setting learning rate to 3.0e-05
# Epoch 0: Validation loss = 0.034371368686093876
# Epoch 1: Validation loss = 0.03436354373873534
# Epoch 2: Validation loss = 0.034032121100573305
# Epoch 3: Validation loss = 0.03405570851725663
# Epoch 4: Validation loss = 0.034322620156771476
# Epoch 5: Validation loss = 0.03457676494980559
# Epoch 6: Validation loss = 0.03462756381185841
# Epoch 7: Validation loss = 0.034288939809883956
# Epoch 8: Validation loss = 0.03450379119372898
# Epoch 9: Validation loss = 0.03447690629898376
# Epoch 10: Validation loss = 0.034265844407974914
# Epoch 11: Validation loss = 0.03420591686038129
# Epoch 12: Validation loss = 0.03394202681171292
# Epoch 13: Validation loss = 0.03395489844048839
# Epoch 14: Validation loss = 0.03399957463571129
# Epoch 15: Validation loss = 0.03370966861644003
# Epoch 16: Validation loss = 0.03342989976612399
# Epoch 17: Validation loss = 0.03383746725549946
# Epoch 18: Validation loss = 0.033727275270114425
# Epoch 19: Validation loss = 0.03349769876311925
# Epoch 20: Validation loss = 0.03365409151138806
# Epoch 21: Validation loss = 0.033441899077967206
# Epoch 22: Validation loss = 0.03323267430490955
# Epoch 23: Validation loss = 0.033814493266003165
# Epoch 24: Validation loss = 0.033715685301297954
# Epoch 25: Validation loss = 0.03370259906747193
# Epoch 26: Validation loss = 0.03347677392054571
# Epoch 27: Validation loss = 0.03372406324414088
# Epoch 28: Validation loss = 0.03364107314201088
# Epoch 29: Validation loss = 0.033740362116562554
# Epoch 30: Validation loss = 0.03361669284159095
# Epoch 31: Validation loss = 0.033772808133010146
# Epoch 32: Validation loss = 0.03362847032407553
# Epoch 33: Validation loss = 0.0336732187279601
# Epoch 34: Validation loss = 0.03432491832681855
# Epoch 35: Validation loss = 0.03340973875274089
# Epoch 36: Validation loss = 0.0332441747132465
# Epoch 37: Validation loss = 0.033188067719110106
# Epoch 38: Validation loss = 0.033408494819663834
# Epoch 39: Validation loss = 0.03380215421391018
# Setting learning rate to 1.0e-05
# Epoch 0: Validation loss = 0.03340816831697764
# Epoch 1: Validation loss = 0.0333756952797211
# Epoch 2: Validation loss = 0.03374991949453577
# Epoch 3: Validation loss = 0.03325487012079423
# Epoch 4: Validation loss = 0.0333921152557142
# Epoch 5: Validation loss = 0.03347008431844599
# Epoch 6: Validation loss = 0.03331686681458349
# Epoch 7: Validation loss = 0.033398441315194725
# Epoch 8: Validation loss = 0.033606286455919954
# Epoch 9: Validation loss = 0.03371043118638987
# Epoch 10: Validation loss = 0.03357152596232098
# Epoch 11: Validation loss = 0.033446641534833774
# Epoch 12: Validation loss = 0.03352456421286141
# Epoch 13: Validation loss = 0.03342669669077214
# Epoch 14: Validation loss = 0.0333582042825317
# Epoch 15: Validation loss = 0.03356473209166404
# Epoch 16: Validation loss = 0.03357545030835724
# Epoch 17: Validation loss = 0.03361927085331896
# Epoch 18: Validation loss = 0.0334763593141687
# Epoch 19: Validation loss = 0.03327821946934858
# Setting learning rate to 3.0e-06
# Epoch 0: Validation loss = 0.03336862504713448
# Epoch 1: Validation loss = 0.03335080106334529
# Epoch 2: Validation loss = 0.033250921363125685
# Epoch 3: Validation loss = 0.033223057907405144
# Epoch 4: Validation loss = 0.03328680979617872
# Epoch 5: Validation loss = 0.03329938887553231
# Epoch 6: Validation loss = 0.03328091793517966
# Epoch 7: Validation loss = 0.03325250421099497
# Epoch 8: Validation loss = 0.03335029738085791
# Epoch 9: Validation loss = 0.03332488777674815
# Epoch 10: Validation loss = 0.03317997902198467
# Epoch 11: Validation loss = 0.03323898314626058
# Epoch 12: Validation loss = 0.03333508207227908
# Epoch 13: Validation loss = 0.03309214729324903
# Epoch 14: Validation loss = 0.03329463620854873
# Epoch 15: Validation loss = 0.033230572815409455
# Epoch 16: Validation loss = 0.033300958127592865
# Epoch 17: Validation loss = 0.03329878839231159
# Epoch 18: Validation loss = 0.03330247625971074
# Epoch 19: Validation loss = 0.03325975894665235
# Setting learning rate to 1.0e-06
# Epoch 0: Validation loss = 0.03320628485338292
# Epoch 1: Validation loss = 0.033226801923525076
# Epoch 2: Validation loss = 0.033218310075130986
# Epoch 3: Validation loss = 0.033204540426500354
# Epoch 4: Validation loss = 0.03320617787687978
# Epoch 5: Validation loss = 0.03322449764602363
# Epoch 6: Validation loss = 0.03324669970690049
# Epoch 7: Validation loss = 0.033270906740020305
# Epoch 8: Validation loss = 0.03324145962741847
# Epoch 9: Validation loss = 0.03322101290674824
# Epoch 10: Validation loss = 0.03320007775042015
# Epoch 11: Validation loss = 0.03315725430834603
# Epoch 12: Validation loss = 0.033158074583718396
# Epoch 13: Validation loss = 0.033178322449909016
# Epoch 14: Validation loss = 0.03316844172826514
# Epoch 15: Validation loss = 0.033175039704285536
# Epoch 16: Validation loss = 0.033143976618987256
# Epoch 17: Validation loss = 0.03313775542031899
# Epoch 18: Validation loss = 0.03311727825161137
# Epoch 19: Validation loss = 0.03311411250960235

# %%
# saving the model for later inference (if training is to be continued another saving method is recommended)
#save_path = './models/AE_2D_v3_bs256_loss00346.pt'
#torch.save(model.state_dict(), save_path)
# model_big = AE_big()
# model_big.load_state_dict(torch.load(save_path))
# model_big.eval()

# %% [markdown]
# ## Evaluation

# %%
model.eval()
# Out:
# AE_2D_v3(
#   (en1): Linear(in_features=4, out_features=100, bias=True)
#   (en2): Linear(in_features=100, out_features=200, bias=True)
#   (en3): Linear(in_features=200, out_features=100, bias=True)
#   (en4): Linear(in_features=100, out_features=2, bias=True)
#   (de1): Linear(in_features=2, out_features=100, bias=True)
#   (de2): Linear(in_features=100, out_features=200, bias=True)
#   (de3): Linear(in_features=200, out_features=100, bias=True)
#   (de4): Linear(in_features=100, out_features=4, bias=True)
#   (tanh): Tanh()
# )

# %%
# Print a few tensors, still normalized
print('Comparing input and output:')
for ii in np.arange(100, 105):
    data = valid_ds.tensors[0][ii]
    pred = model(data)
    print('Inp:', data)
    print('Out:', pred)
    print(' ')
# Out:
# Comparing input and output:
# Inp: tensor([ 1.6863, -0.7095,  1.6946,  0.2721])
# Out: tensor([ 1.6806, -0.5211,  1.4400,  0.0738], grad_fn=<AddBackward0>)
#
# Inp: tensor([ 0.1766, -0.1649, -0.0310, -0.5931])
# Out: tensor([-0.2347, -0.3204, -0.2088, -0.6634], grad_fn=<AddBackward0>)
#
# Inp: tensor([-0.3746,  0.6508,  1.3037, -0.5510])
# Out: tensor([-0.1214,  0.6036,  1.3883, -0.5090], grad_fn=<AddBackward0>)
#
# Inp: tensor([-0.3711, -0.0072,  1.0894, -0.7293])
# Out: tensor([-0.3073, -0.0599,  1.0813, -0.7100], grad_fn=<AddBackward0>)
#
# Inp: tensor([-0.7818, -0.3965,  1.1572, -0.7662])
# Out: tensor([-0.4701, -0.4138,  1.1177, -0.6868], grad_fn=<AddBackward0>)

# %%
# Print a few tensors, now not normalized
print('Comparing input and output:')
for ii in np.arange(100, 105):
    data = valid_ds.tensors[0][ii]
    pred = model(data).detach().numpy()
    pred = np.multiply(pred, train_std.values)
    pred = np.add(pred, train_mean.values)
    data = np.multiply(data, train_std.values)
    data = np.add(data, train_mean.values)
    print('Inp:', data)
    print('Out:', pred)
    print(' ')
# Out:
# Comparing input and output:
# Inp: tensor([430.8397,  -1.1533,   3.0955, 751.4479])
# Out: [430.14423    -0.8527875   2.6317675 638.67285  ]
#
# Inp: tensor([ 2.4776e+02, -2.8475e-01, -4.7715e-02,  2.5939e+02])
# Out: [197.88925    -0.5326693  -0.3714981 219.40454  ]
#
# Inp: tensor([180.9266,   1.0163,   2.3835, 283.3568])
# Out: [211.6227       0.94092697   2.5376241  307.23666   ]
#
# Inp: tensor([ 1.8135e+02, -3.3156e-02,  1.9931e+00,  1.8195e+02])
# Out: [ 1.89079391e+02 -1.17232345e-01  1.97832096e+00  1.92905243e+02]
#
# Inp: tensor([131.5479,  -0.6542,   2.1167, 160.9622])
# Out: [169.34663     -0.68176425   2.0447254  206.09674   ]

# %%
plt.close('all')
unit_list = ['[GeV]', '[rad]', '[rad]', '[GeV]']
variable_list = [r'$p_T$', r'$\eta$', r'$\phi$', r'$E$']
line_style = ['--', '-']
colors = ['orange', 'c']
markers = ['*', 's']


# Histograms
idxs = (0, 100000)  # Choose events to compare
data = torch.tensor(test_x[idxs[0]:idxs[1]].values)
pred = model(data).detach().numpy()
pred = np.multiply(pred, train_std.values)
pred = np.add(pred, train_mean.values)
data = np.multiply(data, train_std.values)
data = np.add(data, train_mean.values)

alph = 0.8
n_bins = 50
for kk in np.arange(4):
    plt.figure(kk + 4)
    n_hist_data, bin_edges, _ = plt.hist(data[:, kk], color=colors[1], label='Input', alpha=1, bins=n_bins)
    n_hist_pred, _, _ = plt.hist(pred[:, kk], color=colors[0], label='Output', alpha=alph, bins=bin_edges)
    plt.suptitle(train.columns[kk])
    plt.xlabel(variable_list[kk] + ' ' + unit_list[kk])
    plt.ylabel('Number of events')
    plt.legend()
    ms.sciy()

# %%
# Plot input on top of output
idxs = (0, 100)  # Choose events to compare
data = torch.tensor(test_x[idxs[0]:idxs[1]].values)
pred = model(data).detach().numpy()
pred = np.multiply(pred, train_std.values)
pred = np.add(pred, train_mean.values)
data = np.multiply(data, train_std.values)
data = np.add(data, train_mean.values)

for kk in np.arange(4):
    plt.figure(kk)
    plt.plot(data[:, kk], color=colors[1], label='Input', linestyle=line_style[1], marker=markers[1])
    plt.plot(pred[:, kk], color=colors[0], label='Output', linestyle=line_style[0], marker=markers[0])
    plt.suptitle(train.columns[kk])
    plt.xlabel('Event')
    plt.ylabel(variable_list[kk] + ' ' + unit_list[kk])
    plt.legend()
    ms.sciy()

# %%
# Plot input on top of output
idxs = (0, int(1e5))  # Choose events to compare
data = torch.tensor(test_x[idxs[0]:idxs[1]].values)
latent = model.encode(data).detach().numpy()

# %%
for ii in np.arange(latent.shape[1]):
    plt.figure()
    plt.hist(latent[:, ii], label='$z_%d$' % (ii + 1), color='m')
    plt.suptitle('Latent variable #%d' % (ii + 1))
    plt.legend()
    ms.sciy()

# %%
mksz = 1

plt.figure()
plt.scatter(latent[:, 0], latent[:, 1], s=mksz)
plt.xlabel(r'$z_1$')
plt.ylabel(r'$z_2$')
# Out:
# Text(0, 0.5, '$z_2$')
