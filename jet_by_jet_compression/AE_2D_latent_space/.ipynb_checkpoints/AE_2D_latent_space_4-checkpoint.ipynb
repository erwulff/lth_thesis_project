# %% [markdown]
# # Jet Compression using an Autoencoder

# %%
import sys
BIN = '../../'
sys.path.append(BIN)
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import pandas as pd

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset

from my_nn_modules import AE_big, get_data, fit

import my_matplotlib_style as ms
mpl.rc_file(BIN + 'my_matplotlib_rcparams')

# %% [markdown]
# ## Loading and preparing the data

# %%
force_cpu = False

if force_cpu:
    device = torch.device('cpu')
else:
    if torch.cuda.is_available():
        device = torch.device('cuda')
    else:
        device = torch.device('cpu')
print('Using device:', device)
# Out:
# Using device: cpu

# %%
# Load data
train = pd.read_pickle(BIN + 'processed_data/train.pkl')
test = pd.read_pickle(BIN + 'processed_data/test.pkl')

train.head(10)
# Out:
#                  pT       eta       phi            E
# 1367643  300.752869  0.118391 -1.460827   303.719818
# 1739612   79.819145  4.535507 -1.185196  3722.832764
# 546066   220.472305  1.314261 -0.943992   440.195190
# 213212    74.533775  0.010658 -0.424795    74.770332
# 150544   220.668121  2.432910 -2.308348  1266.681030
# 574837   159.841782  0.731125 -1.150598   207.133514
# 1171687  306.125305  0.702473  0.437615   385.713013
# 1608254  189.011673 -1.387443  0.490634   403.126709
# 1618830  194.996719 -1.022815 -1.560437   306.534515
# 637947   186.887146 -0.621282 -0.465523   226.002701

# %% [markdown]
# ## Normalizing and splitting into train and test datasets

# %%
# Normalize
train_mean = train.mean()
train_std = train.std()

train = (train - train_mean) / train_std
# Is this the right way to normalize? (only using train mean and std to normalize both train and test)
test = (test - train_mean) / train_std

train_x = train
test_x = test
train_y = train_x  # y = x since we are building and AE
test_y = test_x

train_ds = TensorDataset(torch.tensor(train_x.values), torch.tensor(train_y.values))
valid_ds = TensorDataset(torch.tensor(test_x.values), torch.tensor(test_y.values))

# %% [markdown]
# ## Training

# %%
def mse_loss(input, target, size_average=None, reduce=None, reduction='mean'):
    # type: (Tensor, Tensor, Optional[bool], Optional[bool], str) -> Tensor
    r"""mse_loss(input, target, size_average=None, reduce=None, reduction='mean') -> Tensor

    Measures the element-wise mean squared error.

    See :class:`~torch.nn.MSELoss` for details.
    """
    if not (target.size() == input.size()):
        warnings.warn("Using a target size ({}) that is different to the input size ({}). "
                      "This will likely lead to incorrect results due to broadcasting. "
                      "Please ensure they have the same size.".format(target.size(), input.size()),
                      stacklevel=2)
    if size_average is not None or reduce is not None:
        reduction = _Reduction.legacy_get_string(size_average, reduce)

    ret = (input - target) ** 2
    factor = torch.full(ret.size(), 1)
    factor[:, 2] = 2.4
    ret = ret * factor
    if reduction != 'none':
        ret = torch.mean(ret) if reduction == 'mean' else torch.sum(ret)

    return ret

# %%
bs = 256  # batch size
train_dl, valid_dl = get_data(train_ds, valid_ds, bs)
loss_func = nn.MSELoss()
loss_func = mse_loss

# %%
class AE_2D_v2(nn.Module):
    def __init__(self, n_features=4):
        super(AE_2D_v2, self).__init__()
        self.en1 = nn.Linear(n_features, 50)
        self.en2 = nn.Linear(50, 20)
        self.en3 = nn.Linear(20, 10)
        self.en4 = nn.Linear(10, 2)
        self.de1 = nn.Linear(2, 10)
        self.de2 = nn.Linear(10, 20)
        self.de3 = nn.Linear(20, 50)
        self.de4 = nn.Linear(50, n_features)
        self.tanh = nn.Tanh()

    def encode(self, x):
        return self.en4(self.tanh(self.en3(self.tanh(self.en2(self.tanh(self.en1(x)))))))

    def decode(self, x):
        return self.de4(self.tanh(self.de3(self.tanh(self.de2(self.tanh(self.de1(self.tanh(x))))))))

    def forward(self, x):
        z = self.encode(x)
        return self.decode(z)


class AE_big_2D_v1(nn.Module):
    def __init__(self, n_features=4):
        super(AE_big_2D_v1, self).__init__()
        self.en1 = nn.Linear(n_features, 8)
        self.en2 = nn.Linear(8, 6)
        self.en3 = nn.Linear(6, 4)
        self.en4 = nn.Linear(4, 2)
        self.de1 = nn.Linear(2, 4)
        self.de2 = nn.Linear(4, 6)
        self.de3 = nn.Linear(6, 8)
        self.de4 = nn.Linear(8, n_features)
        self.tanh = nn.Tanh()

    def encode(self, x):
        return self.en4(self.tanh(self.en3(self.tanh(self.en2(self.tanh(self.en1(x)))))))

    def decode(self, x):
        return self.de4(self.tanh(self.de3(self.tanh(self.de2(self.tanh(self.de1(self.tanh(x))))))))

    def forward(self, x):
        z = self.encode(x)
        return self.decode(z)
    

class AE_big_2D_v2(nn.Module):
    def __init__(self, n_features=4):
        super(AE_big_2D_v2, self).__init__()
        self.en1 = nn.Linear(n_features, 8)
        self.en2 = nn.Linear(8, 6)
        self.en3 = nn.Linear(6, 4)
        self.en4 = nn.Linear(4, 3)
        self.en5 = nn.Linear(3, 2)
        self.de1 = nn.Linear(2, 3)
        self.de2 = nn.Linear(3, 4)
        self.de3 = nn.Linear(4, 6)
        self.de4 = nn.Linear(6, 8)
        self.de5 = nn.Linear(8, n_features)
        self.tanh = nn.Tanh()

    def encode(self, x):
        return self.en5(self.tanh(self.en4(self.tanh(self.en3(self.tanh(self.en2(self.tanh(self.en1(x)))))))))

    def decode(self, x):
        return self.de5(self.tanh(self.de4(self.tanh(self.de3(self.tanh(self.de2(self.tanh(self.de1(self.tanh(x))))))))))

    def forward(self, x):
        z = self.encode(x)
        return self.decode(z)

# %%
n_features = len(train.loc[0])
model = AE_2D_v2(n_features=n_features)

# %%
# Training
#epochs_list = [7, 5, 3, 2, 2]
epochs_list = [40, 40, 20, 20, 20]
lrs = [1e-3, 3e-4, 1e-4, 3e-5, 1e-5]
for ii, epochs in enumerate(epochs_list):
    print('Setting learning rate to %.1e' % lrs[ii])
    opt = optim.Adam(model.parameters(), lr=lrs[ii])
    #opt = optim.SGD(model.parameters(), lr=lrs[ii], momentum=0.9, nesterov=True)
    #opt = optim.RMSprop(model.parameters(), lr=lrs[ii], momentum=0.9)
    fit(epochs, model, loss_func, opt, train_dl, valid_dl, device)
# Out:
# Setting learning rate to 1.0e-03
# Epoch 0: Validation loss = 0.14634166380463423
# Epoch 1: Validation loss = 0.12810725064208733
# Epoch 2: Validation loss = 0.11442306052038127
# Epoch 3: Validation loss = 0.10290547262177431
# Epoch 4: Validation loss = 0.09522943386823027
# Epoch 5: Validation loss = 0.09064478851308533
# Epoch 6: Validation loss = 0.0924079183159626
# Epoch 7: Validation loss = 0.09291066195623847
# Epoch 8: Validation loss = 0.09270638212285984
# Epoch 9: Validation loss = 0.08320468203946532
# Epoch 10: Validation loss = 0.08678176105180446
# Epoch 11: Validation loss = 0.08183464625591877
# Epoch 12: Validation loss = 0.0820345159059236
# Epoch 13: Validation loss = 0.08030081006882644
# Epoch 14: Validation loss = 0.07289775370186122
# Epoch 15: Validation loss = 0.07082036709925392
# Epoch 16: Validation loss = 0.06739752192717334
# Epoch 17: Validation loss = 0.07065321642914153
# Epoch 18: Validation loss = 0.06743852524156253
# Epoch 19: Validation loss = 0.0661819452856856
# Epoch 20: Validation loss = 0.07342066367468526
# Epoch 21: Validation loss = 0.07165507276686196
# Epoch 22: Validation loss = 0.07222720801606225
# Epoch 23: Validation loss = 0.06742516886901423
# Epoch 24: Validation loss = 0.06526103125261348
# Epoch 25: Validation loss = 0.07003282339636786
# Epoch 26: Validation loss = 0.06458120188541423
# Epoch 27: Validation loss = 0.0657191943226171
# Epoch 28: Validation loss = 0.0635047628317775
# Epoch 29: Validation loss = 0.06640744084976402
# Epoch 30: Validation loss = 0.06865033502602799
# Epoch 31: Validation loss = 0.07202121198424087
# Epoch 32: Validation loss = 0.06645442332111423
# Epoch 33: Validation loss = 0.06651432835802792
# Epoch 34: Validation loss = 0.06427081716155725
# Epoch 35: Validation loss = 0.06309667963601327
# Epoch 36: Validation loss = 0.05966232143129828
# Epoch 37: Validation loss = 0.061900610744218515
# Epoch 38: Validation loss = 0.06548267829978303
# Epoch 39: Validation loss = 0.0663819062495115
# Setting learning rate to 3.0e-04
# Epoch 0: Validation loss = 0.06189641383518248
# Epoch 1: Validation loss = 0.06193340270034887
# Epoch 2: Validation loss = 0.06128900648516326
# Epoch 3: Validation loss = 0.06051383374888001
# Epoch 4: Validation loss = 0.05899981878292203
# Epoch 5: Validation loss = 0.0591793147460058
# Epoch 6: Validation loss = 0.057246889913650456
# Epoch 7: Validation loss = 0.05768359191697167
# Epoch 8: Validation loss = 0.057333880585982655
# Epoch 9: Validation loss = 0.0568654433851061
# Epoch 10: Validation loss = 0.057069843816877804
# Epoch 11: Validation loss = 0.057693922757875736
# Epoch 12: Validation loss = 0.058926641143938537
# Epoch 13: Validation loss = 0.056861021607466575
# Epoch 14: Validation loss = 0.0554671400621064
# Epoch 15: Validation loss = 0.05625605664049828
# Epoch 16: Validation loss = 0.055719922488803565
# Epoch 17: Validation loss = 0.05500096123838667
# Epoch 18: Validation loss = 0.054677053713101116
# Epoch 19: Validation loss = 0.05485364077961108
# Epoch 20: Validation loss = 0.054764772176493115
# Epoch 21: Validation loss = 0.05424502319651711
# Epoch 22: Validation loss = 0.054281522897410214
# Epoch 23: Validation loss = 0.054413128084532386
# Epoch 24: Validation loss = 0.05460826031254253
# Epoch 25: Validation loss = 0.05463819644451732
# Epoch 26: Validation loss = 0.05300355589787362
# Epoch 27: Validation loss = 0.05273357462017648
# Epoch 28: Validation loss = 0.052567500171015205
# Epoch 29: Validation loss = 0.05193580530925091
# Epoch 30: Validation loss = 0.0512974575216009
# Epoch 31: Validation loss = 0.05250817184903568
# Epoch 32: Validation loss = 0.05196997521594044
# Epoch 33: Validation loss = 0.051897277834264614
# Epoch 34: Validation loss = 0.05216160528558548
# Epoch 35: Validation loss = 0.05115048131279559
# Epoch 36: Validation loss = 0.05073364489255217
# Epoch 37: Validation loss = 0.052053717352308855
# Epoch 38: Validation loss = 0.05270307709592811
# Epoch 39: Validation loss = 0.052087724663616296
# Setting learning rate to 1.0e-04
# Epoch 0: Validation loss = 0.05095140072632689
# Epoch 1: Validation loss = 0.050561675595410305
# Epoch 2: Validation loss = 0.050297654403232445
# Epoch 3: Validation loss = 0.05072468132768932
# Epoch 4: Validation loss = 0.05080639618445475
# Epoch 5: Validation loss = 0.05073086003660845
# Epoch 6: Validation loss = 0.049831553151625116
# Epoch 7: Validation loss = 0.05002257826954843
# Epoch 8: Validation loss = 0.049858931438771834
# Epoch 9: Validation loss = 0.04963818683254421
# Epoch 10: Validation loss = 0.049529447759375726
# Epoch 11: Validation loss = 0.048907231432375686
# Epoch 12: Validation loss = 0.04901244884508764
# Epoch 13: Validation loss = 0.04908963517335333
# Epoch 14: Validation loss = 0.0496126511898417
# Epoch 15: Validation loss = 0.049171013099626244
# Epoch 16: Validation loss = 0.049154753238937345
# Epoch 17: Validation loss = 0.04936045651851193
# Epoch 18: Validation loss = 0.048942759536938225
# Epoch 19: Validation loss = 0.04916376084687739
# Setting learning rate to 3.0e-05
# Epoch 0: Validation loss = 0.048977221774106024
# Epoch 1: Validation loss = 0.04928739255694245
# Epoch 2: Validation loss = 0.04902327928552993
# Epoch 3: Validation loss = 0.04890487379549077
# Epoch 4: Validation loss = 0.04926297099988474
# Epoch 5: Validation loss = 0.04882885426202568
# Epoch 6: Validation loss = 0.04891555338237465
# Epoch 7: Validation loss = 0.04889310932261522
# Epoch 8: Validation loss = 0.04935061804655679
# Epoch 9: Validation loss = 0.048991139600144465
# Epoch 10: Validation loss = 0.04898122306922797
# Epoch 11: Validation loss = 0.04885258465629472
# Epoch 12: Validation loss = 0.04914606979127798
# Epoch 13: Validation loss = 0.049116894156430085
# Epoch 14: Validation loss = 0.04943755269316841
# Epoch 15: Validation loss = 0.04882060784815278
# Epoch 16: Validation loss = 0.04875598103574046
# Epoch 17: Validation loss = 0.04865676508885379
# Epoch 18: Validation loss = 0.04904020521801467
# Epoch 19: Validation loss = 0.04887931870506992
# Setting learning rate to 1.0e-05
# Epoch 0: Validation loss = 0.049006872062135325
# Epoch 1: Validation loss = 0.049005574625562626
# Epoch 2: Validation loss = 0.048914427847071305
# Epoch 3: Validation loss = 0.04911891762750594
# Epoch 4: Validation loss = 0.049006143140852006
# Epoch 5: Validation loss = 0.049010097121631666
# Epoch 6: Validation loss = 0.04874483954413586
# Epoch 7: Validation loss = 0.04898624350053115
# Epoch 8: Validation loss = 0.04899342905836631
# Epoch 9: Validation loss = 0.04893291702160506
# Epoch 10: Validation loss = 0.048838474540980746
# Epoch 11: Validation loss = 0.04880637553750005
# Epoch 12: Validation loss = 0.048907919610306994
# Epoch 13: Validation loss = 0.04887359090202786
# Epoch 14: Validation loss = 0.0487911080611076
# Epoch 15: Validation loss = 0.04872736042813416
# Epoch 16: Validation loss = 0.048738308490897206
# Epoch 17: Validation loss = 0.048700754031525545
# Epoch 18: Validation loss = 0.048776908578849344
# Epoch 19: Validation loss = 0.048740405805392635

# %%
opt = optim.Adam(model.parameters(), lr=3e-4)
fit(20, model, loss_func, opt, train_dl, valid_dl, device)
# Out:
# Epoch 0: Validation loss = 0.04978497538384797
# Epoch 1: Validation loss = 0.050565052470455986
# Epoch 2: Validation loss = 0.05086064688071158
# Epoch 3: Validation loss = 0.04979028436863809
# Epoch 4: Validation loss = 0.05279258770990966
# Epoch 5: Validation loss = 0.0523193890117656
# Epoch 6: Validation loss = 0.05693304401370658
# Epoch 7: Validation loss = 0.055681708801779646
# Epoch 8: Validation loss = 0.05179408040848474
# Epoch 9: Validation loss = 0.05250534280097663
# Epoch 10: Validation loss = 0.051447200176458374
# Epoch 11: Validation loss = 0.053742445330088005
# Epoch 12: Validation loss = 0.05307630307612744
# Epoch 13: Validation loss = 0.05159075608696685
# Epoch 14: Validation loss = 0.05867693015231556
# Epoch 15: Validation loss = 0.05417819264414173
# Epoch 16: Validation loss = 0.05387229596930091
# Epoch 17: Validation loss = 0.05526523746835722
# Epoch 18: Validation loss = 0.0534414516767046
# Epoch 19: Validation loss = 0.05186440062961571

# %%
opt = optim.Adam(model.parameters(), lr=3e-5)
fit(20, model, loss_func, opt, train_dl, valid_dl, device)
# Out:
# Epoch 0: Validation loss = 0.050484855236968045
# Epoch 1: Validation loss = 0.049709889457356736
# Epoch 2: Validation loss = 0.0499715452632431
# Epoch 3: Validation loss = 0.050656883858075485
# Epoch 4: Validation loss = 0.05010727676931151
# Epoch 5: Validation loss = 0.04983659524887934
# Epoch 6: Validation loss = 0.05052007890657173
# Epoch 7: Validation loss = 0.049807594131022995
# Epoch 8: Validation loss = 0.05003516367430521
# Epoch 9: Validation loss = 0.05049734243675924
# Epoch 10: Validation loss = 0.04989584837565778
# Epoch 11: Validation loss = 0.05010903709819166
# Epoch 12: Validation loss = 0.0494197776313265
# Epoch 13: Validation loss = 0.049617523442727844
# Epoch 14: Validation loss = 0.049030158603589544
# Epoch 15: Validation loss = 0.05018894418697551
# Epoch 16: Validation loss = 0.050232190822545604
# Epoch 17: Validation loss = 0.05005459507203585
# Epoch 18: Validation loss = 0.0507590013386424
# Epoch 19: Validation loss = 0.05033123960497296

# %%
opt = optim.Adam(model.parameters(), lr=3e-5)
fit(20, model, loss_func, opt, train_dl, valid_dl, device)
# Out:
# Epoch 0: Validation loss = 0.049953100744701794
# Epoch 1: Validation loss = 0.04984185387897218
# Epoch 2: Validation loss = 0.049724005735858195
# Epoch 3: Validation loss = 0.04977571753398881
# Epoch 4: Validation loss = 0.04974698532239217
# Epoch 5: Validation loss = 0.04980289919749909
# Epoch 6: Validation loss = 0.04979333402146035
# Epoch 7: Validation loss = 0.049813670547115836
# Epoch 8: Validation loss = 0.04973201490561791
# Epoch 9: Validation loss = 0.049684844135986735
# Epoch 10: Validation loss = 0.049356366692053136
# Epoch 11: Validation loss = 0.04964538119285681
# Epoch 12: Validation loss = 0.04948788217598691
# Epoch 13: Validation loss = 0.049431095087657195
# Epoch 14: Validation loss = 0.04938943438483251
# Epoch 15: Validation loss = 0.049132841746825466
# Epoch 16: Validation loss = 0.049113885409848346
# Epoch 17: Validation loss = 0.04907439542758968
# Epoch 18: Validation loss = 0.049117820520655914
# Epoch 19: Validation loss = 0.049039317867208464

# %%
opt = optim.Adam(model.parameters(), lr=1e-4)
fit(20, model, loss_func, opt, train_dl, valid_dl, device)
# Out:
# Epoch 0: Validation loss = 0.048959876804214264
# Epoch 1: Validation loss = 0.049890312352137756
# Epoch 2: Validation loss = 0.05126367083957597
# Epoch 3: Validation loss = 0.05038749487044213
# Epoch 4: Validation loss = 0.05102660322627791
# Epoch 5: Validation loss = 0.05065486008321403
# Epoch 6: Validation loss = 0.050885793477092524
# Epoch 7: Validation loss = 0.049674510036591436
# Epoch 8: Validation loss = 0.05005507886142056
# Epoch 9: Validation loss = 0.04987050855176076
# Epoch 10: Validation loss = 0.05057200687007822
# Epoch 11: Validation loss = 0.051315399581024775
# Epoch 12: Validation loss = 0.050271675354685366
# Epoch 13: Validation loss = 0.04992698474909659
# Epoch 14: Validation loss = 0.0492233422380505
# Epoch 15: Validation loss = 0.04919547875945906
# Epoch 16: Validation loss = 0.048934732309496014
# Epoch 17: Validation loss = 0.048888815822850644
# Epoch 18: Validation loss = 0.048906919539444885
# Epoch 19: Validation loss = 0.04810570365341239

# %%
# saving the model for later inference (if training is to be continued another saving method is recommended)
#save_path = './models/AE_2D_v2_bs256_loss00487.pt'
#torch.save(model.state_dict(), save_path)
# model_big = AE_big()
# model_big.load_state_dict(torch.load(save_path))
# model_big.eval()

# %% [markdown]
# ## Evaluation

# %%
model.eval()
# Out:
# AE_2D_v2(
#   (en1): Linear(in_features=4, out_features=50, bias=True)
#   (en2): Linear(in_features=50, out_features=20, bias=True)
#   (en3): Linear(in_features=20, out_features=10, bias=True)
#   (en4): Linear(in_features=10, out_features=2, bias=True)
#   (de1): Linear(in_features=2, out_features=10, bias=True)
#   (de2): Linear(in_features=10, out_features=20, bias=True)
#   (de3): Linear(in_features=20, out_features=50, bias=True)
#   (de4): Linear(in_features=50, out_features=4, bias=True)
#   (tanh): Tanh()
# )

# %%
# Print a few tensors, still normalized
print('Comparing input and output:')
for ii in np.arange(100, 105):
    data = valid_ds.tensors[0][ii]
    pred = model(data)
    print('Inp:', data)
    print('Out:', pred)
    print(' ')
# Out:
# Comparing input and output:
# Inp: tensor([ 1.6863, -0.7095,  1.6946,  0.2721])
# Out: tensor([ 1.9840, -0.5636,  1.6364,  0.2654], grad_fn=<AddBackward0>)
#
# Inp: tensor([ 0.1766, -0.1649, -0.0310, -0.5931])
# Out: tensor([ 0.0919, -0.0790,  0.0087, -0.5871], grad_fn=<AddBackward0>)
#
# Inp: tensor([-0.3746,  0.6508,  1.3037, -0.5510])
# Out: tensor([-0.2124,  0.5946,  1.2826, -0.5158], grad_fn=<AddBackward0>)
#
# Inp: tensor([-0.3711, -0.0072,  1.0894, -0.7293])
# Out: tensor([-0.3490, -0.0336,  1.0819, -0.7232], grad_fn=<AddBackward0>)
#
# Inp: tensor([-0.7818, -0.3965,  1.1572, -0.7662])
# Out: tensor([-0.4092, -0.4565,  1.0898, -0.6528], grad_fn=<AddBackward0>)

# %%
# Print a few tensors, now not normalized
print('Comparing input and output:')
for ii in np.arange(100, 105):
    data = valid_ds.tensors[0][ii]
    pred = model(data).detach().numpy()
    pred = np.multiply(pred, train_std.values)
    pred = np.add(pred, train_mean.values)
    data = np.multiply(data, train_std.values)
    data = np.add(data, train_mean.values)
    print('Inp:', data)
    print('Out:', pred)
    print(' ')
# Out:
# Comparing input and output:
# Inp: tensor([430.8397,  -1.1533,   3.0955, 751.4479])
# Out: [466.9369      -0.92055607   2.9894981  747.6384    ]
#
# Inp: tensor([ 2.4776e+02, -2.8475e-01, -4.7715e-02,  2.5939e+02])
# Out: [ 2.3749228e+02 -1.4768130e-01  2.4637159e-02  2.6279330e+02]
#
# Inp: tensor([180.9266,   1.0163,   2.3835, 283.3568])
# Out: [200.5962      0.9265855   2.3450441 303.32687  ]
#
# Inp: tensor([ 1.8135e+02, -3.3156e-02,  1.9931e+00,  1.8195e+02])
# Out: [ 1.8402644e+02 -7.5247563e-02  1.9795456e+00  1.8543771e+02]
#
# Inp: tensor([131.5479,  -0.6542,   2.1167, 160.9622])
# Out: [176.72855    -0.7498278   1.9939115 225.43015  ]

# %%
plt.close('all')
unit_list = ['[GeV]', '[rad]', '[rad]', '[GeV]']
variable_list = [r'$p_T$', r'$\eta$', r'$\phi$', r'$E$']
line_style = ['--', '-']
colors = ['orange', 'c']
markers = ['*', 's']


# Histograms
idxs = (0, 100000)  # Choose events to compare
data = torch.tensor(test_x[idxs[0]:idxs[1]].values)
pred = model(data).detach().numpy()
pred = np.multiply(pred, train_std.values)
pred = np.add(pred, train_mean.values)
data = np.multiply(data, train_std.values)
data = np.add(data, train_mean.values)

alph = 0.8
n_bins = 50
for kk in np.arange(4):
    plt.figure(kk + 4)
    n_hist_data, bin_edges, _ = plt.hist(data[:, kk], color=colors[1], label='Input', alpha=1, bins=n_bins)
    n_hist_pred, _, _ = plt.hist(pred[:, kk], color=colors[0], label='Output', alpha=alph, bins=bin_edges)
    plt.suptitle(train.columns[kk])
    plt.xlabel(variable_list[kk] + ' ' + unit_list[kk])
    plt.ylabel('Number of events')
    plt.legend()
    ms.sciy()

# %%
# Plot input on top of output
idxs = (0, 100)  # Choose events to compare
data = torch.tensor(test_x[idxs[0]:idxs[1]].values)
pred = model(data).detach().numpy()
pred = np.multiply(pred, train_std.values)
pred = np.add(pred, train_mean.values)
data = np.multiply(data, train_std.values)
data = np.add(data, train_mean.values)

for kk in np.arange(4):
    plt.figure(kk)
    plt.plot(data[:, kk], color=colors[1], label='Input', linestyle=line_style[1], marker=markers[1])
    plt.plot(pred[:, kk], color=colors[0], label='Output', linestyle=line_style[0], marker=markers[0])
    plt.suptitle(train.columns[kk])
    plt.xlabel('Event')
    plt.ylabel(variable_list[kk] + ' ' + unit_list[kk])
    plt.legend()
    ms.sciy()

# %% [markdown]
# ## Exploring the latent space

# %%
# Plot input on top of output
idxs = (0, int(1.9e6))  # Choose events to compare
data = torch.tensor(test_x[idxs[0]:idxs[1]].values)
latent = model.encode(data).detach().numpy()

# %%
for ii in np.arange(latent.shape[1]):
    plt.figure()
    plt.hist(latent[:, ii], label='$z_%d$' % (ii + 1), color='m')
    plt.suptitle('Latent variable #%d' % (ii + 1))
    plt.legend()
    ms.sciy()

# %%
mksz = 1

plt.figure()
plt.scatter(latent[:, 0], latent[:, 1], s=mksz)
plt.xlabel(r'$z_1$')
plt.ylabel(r'$z_2$')
# Out:
# Text(0, 0.5, '$z_2$')
